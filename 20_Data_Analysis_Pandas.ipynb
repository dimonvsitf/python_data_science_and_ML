# %%
# !pip install pandas

# %%
cd datasets/
# Out:
# /home/gptuser/courses/ai-feb-2024/datasets

# %%
pwd
# Out:
# '/home/gptuser/courses/ai-feb-2024/datasets'

# %%
# !wget https://www.innosoft.ai/wp-content/uploads/2024/02/Salaries.csv
# Out:
# --2024-02-17 19:05:43--  https://www.innosoft.ai/wp-content/uploads/2024/02/Salaries.csv
# Resolving www.innosoft.ai (www.innosoft.ai)... 50.116.23.119
# Connecting to www.innosoft.ai (www.innosoft.ai)|50.116.23.119|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16239776 (15M) [text/csv]
# Saving to: ‘Salaries.csv.2’
#
# Salaries.csv.2      100%[===================>]  15.49M  5.02MB/s    in 3.1s
#
# 2024-02-17 19:05:47 (5.02 MB/s) - ‘Salaries.csv.2’ saved [16239776/16239776]

# %%
import pandas as pd

# %%
pwd
# Out:
# '/home/gptuser/courses/ai-feb-2024/datasets'

# %%
cd ..
# Out:
# /home/gptuser/courses/ai-feb-2024

# %%
pwd
# Out:
# '/home/gptuser/courses/ai-feb-2024'

# %%
pwd
# Out:
# '/home/gptuser/courses/ai-feb-2024'

# %%
salaries = pd.read_csv('datasets/Salaries.csv')

# %%
salaries.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
salaries.tail()
# Out:
#             Id   EmployeeName                    JobTitle  BasePay  \
# 148649  148650  Roy I Tillery                   Custodian      0.0
# 148650  148651   Not provided                Not provided      NaN
# 148651  148652   Not provided                Not provided      NaN
# 148652  148653   Not provided                Not provided      NaN
# 148653  148654      Joe Lopez  Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148649          0.0      0.00       0.0      0.00              0.00  2014
# 148650          NaN       NaN       NaN      0.00              0.00  2014
# 148651          NaN       NaN       NaN      0.00              0.00  2014
# 148652          NaN       NaN       NaN      0.00              0.00  2014
# 148653          0.0   -618.13       0.0   -618.13           -618.13  2014
#
#         Notes         Agency  Status
# 148649    NaN  San Francisco     NaN
# 148650    NaN  San Francisco     NaN
# ...

# %%
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
salaries.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448840    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes  \
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %%
salaries.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
my_report = salaries.describe()[['BasePay', 'Benefits']]

# %%
type(my_report)
# Out:
# pandas.core.frame.DataFrame

# %%
my_report
# Out:
#              BasePay       Benefits
# count  148045.000000  112491.000000
# mean    66325.448840   25007.893151
# std     42764.635495   15402.215858
# min      -166.010000     -33.890000
# 25%     33588.200000   11535.395000
# 50%     65007.450000   28628.620000
# 75%     94691.050000   35566.855000
# max    319275.010000   96570.660000

# %%
my_report.to_csv('datasets/my_report.csv')

# %%
salaries['BasePay'].mean()
# Out:
# 66325.4488404877

# %%
salaries['BasePay'].max()
# Out:
# 319275.01

# %%
salaries['BasePay'].min()
# Out:
# -166.01

# %%
round(salaries['BasePay'].mean(), 2)
# Out:
# 66325.45

# %%
salaries[salaries['OvertimePay'] == salaries['OvertimePay'].max()]
# Out:
#    Id  EmployeeName                         JobTitle    BasePay  OvertimePay  \
# 1   2  GARY JIMENEZ  CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
#
#     OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 1  137811.38       NaN  538909.28         538909.28  2011    NaN
#
#           Agency  Status
# 1  San Francisco     NaN

# %%
salaries.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
selected_salaries = salaries[['Year', 'BasePay', 'OvertimePay']]

# %%
data_per_year = selected_salaries.groupby('Year').mean()

# %%
data_per_year
# Out:
#            BasePay  OvertimePay
# Year
# 2011  63595.956517  4531.065429
# 2012  65436.406857  5023.417824
# 2013  69630.030216  5281.641980
# 2014  66564.421924  5401.993737

# %%
data_per_year = data_per_year.reset_index()

# %%
data_per_year
# Out:
#    Year       BasePay  OvertimePay
# 0  2011  63595.956517  4531.065429
# 1  2012  65436.406857  5023.417824
# 2  2013  69630.030216  5281.641980
# 3  2014  66564.421924  5401.993737

# %%
import seaborn as sns

# %%
sns.lineplot(x = data_per_year['Year'], 
             y = data_per_year['BasePay'])
# Out:
# <Axes: xlabel='Year', ylabel='BasePay'>

# %%
salaries.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
salaries.iloc[-100:]
# Out:
#             Id         EmployeeName                    JobTitle  BasePay  \
# 148554  148555      Lawrence F Gatt       Fire Alarm Dispatcher    73.33
# 148555  148556       Carlos E Ortiz   Senior Eligibility Worker     0.00
# 148556  148557  Paulina U Armstrong   Senior Eligibility Worker     0.00
# 148557  148558       Hattie M Breed           Recreation Leader    73.06
# 148558  148559     Addison G Wright              Camp Assistant    71.03
# ...        ...                  ...                         ...      ...
# 148649  148650        Roy I Tillery                   Custodian     0.00
# 148650  148651         Not provided                Not provided      NaN
# 148651  148652         Not provided                Not provided      NaN
# 148652  148653         Not provided                Not provided      NaN
# 148653  148654            Joe Lopez  Counselor, Log Cabin Ranch     0.00
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# ...

# %%
selected_records = salaries.iloc[5001:5201]

# %%
selected_records
# Out:
#         Id       EmployeeName                   JobTitle    BasePay  \
# 5001  5002         MARY BURNS         POLICE OFFICER III  112417.28
# 5002  5003       JOSEPH DUFFY  SENIOR BUILDING INSPECTOR  110754.80
# 5003  5004        JORGE GARZA             DEPUTY SHERIFF   86840.00
# 5004  5005  NATALIE KOMARCHUK         POLICE OFFICER III  112401.08
# 5005  5006      ROBERT CANEDO         POLICE OFFICER III  112401.05
# ...    ...                ...                        ...        ...
# 5196  5197   KIMBERLEE KIMURA         DEPUTY DIRECTOR II  123290.70
# 5197  5198     STACEY CAMILLO                MANAGER III  123290.70
# 5198  5199   DAVID DEL GRANDE                MANAGER III  123290.70
# 5199  5200     JOANNA FRAGULI                MANAGER III  123290.70
# 5200  5201      DANIEL HOMSEY                MANAGER III  123290.70
#
#       OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# 5001      2060.43   9746.05       NaN  124223.76         124223.76  2011
# ...

# %%
selected_records.describe()
# Out:
#                 Id        BasePay   OvertimePay      OtherPay  Benefits  \
# count   200.000000     200.000000    200.000000    200.000000       0.0
# mean   5101.500000  112174.197000   5374.165800   6070.223500       NaN
# std      57.879185   12093.288578   9843.879626   6379.552514       NaN
# min    5002.000000   65793.280000      0.000000      0.000000       NaN
# 25%    5051.750000  105934.667500      0.000000      0.000000       NaN
# 50%    5101.500000  112421.395000    745.895000   4657.025000       NaN
# 75%    5151.250000  123290.700000   6923.427500  10346.105000       NaN
# max    5201.000000  124153.780000  54828.460000  26915.270000       NaN
#
#            TotalPay  TotalPayBenefits    Year  Notes  Status
# count     200.00000         200.00000   200.0    0.0     0.0
# mean   123618.58630      123618.58630  2011.0    NaN     NaN
# std       307.38064         307.38064     0.0    NaN     NaN
# min    123290.70000      123290.70000  2011.0    NaN     NaN
# ...
